# %%
import sys
sys.path.append('../src')
from optimal_explorer.mdps.bandits import (
        play_bandit_best_arm_selection_interactive,
        BanditBestArmSelection,
    )

# %%
# play_bandit_best_arm_selection_interactive()
# Out:
# Welcome to Bandit Best Arm Selection! You have 20 steps to explore the arms.
# Arms: blue, green, red, yellow, purple
# Enter 'q' to quit at any time.
# You chose 'blue' and received reward 1
# You chose 'green' and received reward 0
# You chose 'red' and received reward 0
# 'yellew' is not a valid arm. Please try again.
# You chose 'yellow' and received reward 1
# You chose 'purple' and received reward 0
# You chose 'blue' and received reward 0
# You chose 'green' and received reward 1
# You chose 'red' and received reward 0
# You chose 'yellow' and received reward 1
# You chose 'purple' and received reward 1
# You chose 'blue' and received reward 0
# You chose 'green' and received reward 0
# You chose 'yellow' and received reward 1
# You chose 'purple' and received reward 1
# You chose 'yellow' and received reward 0
# You chose 'purple' and received reward 0
# You chose 'yellow' and received reward 0
# You chose 'purple' and received reward 0
# You chose 'yellow' and received reward 1
# You chose 'purple' and received reward 0
# You have exhausted your budget for trying out different choices.
# Your final answer: 'yellow'
# Correct! 🎉 You identified the best arm.

# %%
mdp = BanditBestArmSelection()
mdp.reset()
# Out:
# {'current_step': 0,
#  'max_steps': 20,
#  'history': [],
#  'arm_names': ['blue', 'green', 'red', 'yellow', 'purple'],
#  'final_answer': None}

# %%
mdp.step('blue')
# Out:
# ({'current_step': 1,
#   'max_steps': 20,
#   'history': [('blue', 0)],
#   'arm_names': ['blue', 'green', 'red', 'yellow', 'purple'],
#   'final_answer': None},
#  0.0,
#  False,
#  {'reward': 0})

# %%
mdp.step('yellow')
# Out:
# ({'current_step': 2,
#   'max_steps': 20,
#   'history': [('blue', 0), ('yellow', 0)],
#   'arm_names': ['blue', 'green', 'red', 'yellow', 'purple'],
#   'final_answer': None},
#  0.0,
#  False,
#  {'reward': 0})

# %%
mdp.step('yellow')
# Out:
# ({'current_step': 3,
#   'max_steps': 20,
#   'history': [('blue', 0), ('yellow', 0), ('yellow', 0)],
#   'arm_names': ['blue', 'green', 'red', 'yellow', 'purple'],
#   'final_answer': None},
#  0.0,
#  False,
#  {'reward': 0})

# %%
mdp.step('yellow')
# Out:
# ({'current_step': 4,
#   'max_steps': 20,
#   'history': [('blue', 0), ('yellow', 0), ('yellow', 0), ('yellow', 0)],
#   'arm_names': ['blue', 'green', 'red', 'yellow', 'purple'],
#   'final_answer': None},
#  0.0,
#  False,
#  {'reward': 0})

# %%
mdp.step('purple')
# Out:
# ({'current_step': 6,
#   'max_steps': 20,
#   'history': [('blue', 0),
#    ('yellow', 0),
#    ('yellow', 0),
#    ('yellow', 0),
#    ('yellow', 0),
#    ('purple', 0)],
#   'arm_names': ['blue', 'green', 'red', 'yellow', 'purple'],
#   'final_answer': None},
#  0.0,
#  False,
#  {'reward': 0})

# %%
mdp.step('purple')
# Out:
# ({'current_step': 7,
#   'max_steps': 20,
#   'history': [('blue', 0),
#    ('yellow', 0),
#    ('yellow', 0),
#    ('yellow', 0),
#    ('yellow', 0),
#    ('purple', 0),
#    ('purple', 0)],
#   'arm_names': ['blue', 'green', 'red', 'yellow', 'purple'],
#   'final_answer': None},
#  0.0,
#  False,
#  {'reward': 0})

# %%
mdp.step('red')
# Out:
# ({'current_step': 8,
#   'max_steps': 20,
#   'history': [('blue', 0),
#    ('yellow', 0),
#    ('yellow', 0),
#    ('yellow', 0),
#    ('yellow', 0),
#    ('purple', 0),
#    ('purple', 0),
#    ('red', 0)],
#   'arm_names': ['blue', 'green', 'red', 'yellow', 'purple'],
#   'final_answer': None},
#  0.0,
#  False,
#  {'reward': 0})

# %%
mdp.step('red')
# Out:
# ({'current_step': 9,
#   'max_steps': 20,
#   'history': [('blue', 0),
#    ('yellow', 0),
#    ('yellow', 0),
#    ('yellow', 0),
#    ('yellow', 0),
#    ('purple', 0),
#    ('purple', 0),
#    ('red', 0),
#    ('red', 0)],
#   'arm_names': ['blue', 'green', 'red', 'yellow', 'purple'],
#   'final_answer': None},
#  0.0,
#  False,
#  {'reward': 0})

# %%
mdp.step('blue')
# Out:
# ({'current_step': 10,
#   'max_steps': 20,
#   'history': [('blue', 0),
#    ('yellow', 0),
#    ('yellow', 0),
#    ('yellow', 0),
#    ('yellow', 0),
#    ('purple', 0),
#    ('purple', 0),
#    ('red', 0),
#    ('red', 0),
#    ('blue', 1)],
#   'arm_names': ['blue', 'green', 'red', 'yellow', 'purple'],
#   'final_answer': None},
#  0.0,
#  False,
#  {'reward': 1})
