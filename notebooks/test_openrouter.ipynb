# %%
import sys
import asyncio
from typing import List, Dict, Tuple
import random
from pathlib import Path
import json
from datetime import datetime
from pprint import pprint as pp

# Add parent directory to path to import from mdps
sys.path.append('../src/optimal_explorer')
from llm_utils import llm_call

# %%
data = await llm_call(
    model='o3',
    system='You are a helpless assistant.',
    user='What is lolmax and how does it work?',
    temperature=0.1,
    get_everything=True,
)

# %%
data.keys()
# Out:
# dict_keys(['id', 'provider', 'model', 'object', 'created', 'choices', 'usage'])

# %%
data['choices'][0]['message'].keys()
# Out:
# dict_keys(['role', 'content', 'refusal', 'reasoning', 'reasoning_details'])

# %%
pp(data['choices'][0]['message'])
# Out:
# {'content': 'I’m afraid I’m not completely certain which “lolmax” you have in '
#             'mind—the word turns up in a handful of unrelated places. Below '
#             'are the three usages you’ll most often run into, with a short '
#             'description of how each one “works.” If none of these matches '
#             'what you’re looking for, please let me know a bit more about the '
#             'context (software, medicine, gaming slang, etc.) and I can try '
#             'again.\n'
#             '\n'
#             '1. Internet-slang “LOL-max”  \n'
#             '   • Meaning: An emphatic form of “LOL” (“laugh out loud”) that '
#             'implies “maximum laughter.”  \n'
#             '   • How it works: There’s no mechanism—just emphasis. Writers '
#             'append “max,” “++,” or similar boosters after “LOL” to show the '
#             'joke was especially funny (e.g., “That meme was LOL-max!”).\n'
#             '\n'
#             '2. Allergy medication brand (India and a few other markets)  \n'
#             '   • Trade name: Lolmax-L, Lolmax-M, etc.  \n'
#             '   • Active ingredients: Typically a combination of '
#             'Levocetirizine (an antihistamine) and Montelukast (a '
#             'leukotriene-receptor antagonist).  \n'
#             '   • How it works:  \n'
#             '     – Levocetirizine blocks H1-histamine receptors, reducing '
#             'sneezing, runny nose, and itching.  \n'
#             '     – Montelukast blocks leukotriene receptors, cutting down '
#             'inflammation and bronchial constriction.  \n'
#             '     – Taken together (usually one tablet daily), they provide '
#             'broader relief for allergic rhinitis or mild asthma than either '
#             'drug alone.\n'
#             '\n'
#             '3. Third-party League of Legends utility (“LoLMax” or similar)  \n'
#             '   • What it is: A small, unofficial Windows tool sometimes '
#             'shared in modding communities. Typical functions include FPS '
#             'capping, quick-launch macros, or simple game overlays.  \n'
#             '   • How it works:  \n'
#             '     – Hooks into the League of Legends client executable.  \n'
#             '     – Reads or modifies in-memory values such as max frame rate, '
#             'screen resolution, or hotkey mappings.  \n'
#             '     – Because it interferes with the game process, it runs the '
#             'risk of triggering Riot’s anti-cheat (Vanguard) and can get your '
#             'account banned. Use at your own risk.\n'
#             '\n'
#             'Again, if your “lolmax” is something entirely different—an '
#             'algorithm, a file-format, a meme, or a piece of hardware—just '
#             'tell me a bit more and I’ll do my best to track it down.',
#  'reasoning': '**Researching "lolmax"**\n'
#               '\n'
#               'I’m diving into the term "lolmax" and finding a few '
#               'possibilities. It seems to be used on Reddit as "Laugh Out Loud '
#               'Maximum." There might be something related to cryptography or a '
#               "digital root algorithm. Plus, there's a gaming patch labeled "
#               '"LOLMax" that could be about League of Legends. I’m also '
#               'considering that it might refer to a medication or maybe a term '
#               "from robotics. There's a lot to unpack here, and I'm curious "
#               'about all these angles!**Exploring "lolmax" meanings**\n'
#               '\n'
#               'I\'m considering what "lolmax" could refer to. It might be a '
#               'medication name or a term in signal processing like "long '
#               'latency maximum." However, I could clarify for the user that '
#               '"lolmax" isn\'t widely recognized and may blend ideas from meme '
#               "culture, where it refers to something extremely funny. There's "
#               'also a possibility it relates to GPU mining or could even be a '
#               'library for managing concurrency. Asking for clarification '
#               'might help narrow it down!**Clarifying "lolmax" meaning**\n'
#               '\n'
#               'I\'m exploring the term "lolmax," which seems to have multiple '
#               'meanings that vary by context. It could refer to internet slang '
#               'for "maximal laughter," a pharmaceutical brand for medications '
#               'like Levocetirizine and Montelukast, or perhaps a gaming tool '
#               "related to League of Legends. Since it's not a widely "
#               "recognized term, I'll need to ask the user for clarification on "
#               "which meaning they intended. It's important to provide a clear "
#               'answer while noting the uncertainty!',
#  'reasoning_details': [{'data': 'gAAAAABoUCn14Oj3ALT3fVYUiUeblhQG3BsflfY5WGs3qW2oM0NQ3jUUukdssn-5x0W5Q3zlDUG7tP5zLxRiWFl-m9laTmz4cnKr91nxxh-3n6omDsPCOSm-K7S1V5KjbDf-RiNywKrdIzLdtSbxsSEhUjcQ301z_h6EKi2rG89JaY7ZAJBND-zT0v71CxLDrWgWEH85zYkkN8RRmtf44KDJ-PBMnjW93PVUodaPTQXIBqKqfz5QZJLdQbQ_4nEwN9Wtcs35NHpHw3EKTTHY69XkHu0fXlhRhkz3o9lWHid9Tn0Sv8Y5Fit4S4BtZGV5Y5ygc_k_yfeWa_EEGLeWyDfS6107s910FdB2uZRmVH-agv-sNozUhI72GEXzpff1MuzXcVp_gYYyEhlS-n2XvZ6bdpZ8hHaAvLYrF5ZsToheLA_SNEJVaQhiwmX4IKQyuNNNA3rkAMzFEHNcy0Gif5GD0a-xLpEr9_jjbfS9wuM8_262fwc6FYDSIiWxPWT3bXDeo_xBUchq3ydSXmsQP9g3EcH6_LEHPZeS8D7LdxjQ1QJgWncro2xC50M4oSsWQoY1AWUxnvBLGE5dAgIESzkChzoPVTm6jqT6ZnRyPfVAmC_fGveBnxukNVTPK1688l-sXOACyZEzV2mJ72pI3oI67LupsCWgyTAnyWNYUHvcCHK97hLcaWU3JwO0ce9lhwjEsBZJn-hvcNJpknUh33MTUvbGkXgchc73oLu1zAuBI2_RCViwP8JcWm2fzEreKEQ1vtpZsYwAhAO2z5233-fAaor5OEx6kEMomvv1Fubn5BzExNiLIHCfjBd