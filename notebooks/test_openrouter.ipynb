# %%
import sys
import asyncio
from typing import List, Dict, Tuple
import random
from pathlib import Path
import json
from datetime import datetime
from pprint import pprint as pp

# Add parent directory to path to import from mdps
sys.path.append('../src/optimal_explorer')
from llm_utils import llm_call

# %%
data = await llm_call(
    model='deepseek/deepseek-r1-0528',
    system='You are a helpless assistant.',
    user='What is lolmax and how does it work?',
    temperature=0.1,
    get_everything=True,
)

# %%
data.keys()
# Out:
# dict_keys(['id', 'provider', 'model', 'object', 'created', 'choices', 'usage'])

# %%
data['choices'][0]['message'].keys()
# Out:
# dict_keys(['role', 'content', 'refusal', 'reasoning'])

# %%
type(data['choices'][0]['message']['reasoning'])
# Out:
# str
